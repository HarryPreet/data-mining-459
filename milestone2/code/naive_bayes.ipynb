# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold, train_test_split, cross_val_score
from sklearn.metrics import f1_score
from collections import Counter
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Some Preprocessing

# %%
train= pd.read_csv('data/train_best.csv')
test= pd.read_csv('data/test_best.csv')

# %%
train['date_confirmation'].describe(percentiles=[0.2, 0.4, 0.6, 0.8])
# Out:
# count    17212.000000
# mean       126.737160
# std         21.321449
# min          5.000000
# 20%        106.000000
# 40%        128.000000
# 50%        132.000000
# 60%        138.000000
# 80%        145.000000
# max        154.000000
# Name: date_confirmation, dtype: float64

# %%
train['date_confirmation'] = round(train['date_confirmation'].rank(pct=True) * 10).astype('int64')

test['date_confirmation'] = round(test['date_confirmation'].rank(pct=True) * 10).astype('int64')

# %%
# from imblearn.under_sampling import RandomUnderSampler 
# from imblearn.over_sampling import RandomOverSampler

# labels = train.loc[:,train.columns == 'outcome_group']
# features = train.loc[:,train.columns != 'outcome_group']
# counter = Counter(labels['outcome_group'])
# print("Total Samples Before Balancing: ",len(train), "Distribution of Classes:", counter)
# over = RandomOverSampler({2.0:5680 ,0.0:5680})
# under = RandomUnderSampler({1.0:5680})
# features,labels = under.fit_resample(features,labels)
# features,labels = over.fit_resample(features,labels)
# counter = Counter(labels['outcome_group'])
# features['outcome_group'] = labels['outcome_group']
# train = features
# print("Total Samples After Balancing: ",len(train), "Distribution of Classes:", counter)

# %% [markdown]
# # Training of Model

# %%
train = train.drop(['latitude', 'longitude', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Case_Fatality_Ratio', 'Incident_Rate'], axis=1)

train
# Out:
#        age  sex  country  date_confirmation  chronic_disease_binary  \
# 0       18  0.0     21.0                  6                     0.0
# 1       27  0.0     27.0                  2                     0.0
# 2       46  1.0     21.0                  3                     0.0
# 3       21  0.0     21.0                  8                     0.0
# 4       27  1.0     21.0                  8                     0.0
# ...    ...  ...      ...                ...                     ...
# 17207   29  0.0     21.0                  3                     0.0
# 17208   47  0.0     27.0                  1                     0.0
# 17209   30  1.0     21.0                  8                     0.0
# 17210   59  1.0     21.0                 10                     0.0
# 17211   28  1.0     27.0                  5                     0.0
#
#        outcome_group
# 0                1.0
# 1                2.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 17207            1.0
# 17208            2.0
# 17209            1.0
# 17210            1.0
# 17211            0.0
#
# [17212 rows x 6 columns]

# %%
X = train.loc[:, train.columns!='outcome_group']
y = pd.DataFrame(train, columns=['outcome_group'])

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#print(X.shape, y.shape)

X
# Out:
#        age  sex  country  date_confirmation  chronic_disease_binary
# 0       18  0.0     21.0                  6                     0.0
# 1       27  0.0     27.0                  2                     0.0
# 2       46  1.0     21.0                  3                     0.0
# 3       21  0.0     21.0                  8                     0.0
# 4       27  1.0     21.0                  8                     0.0
# ...    ...  ...      ...                ...                     ...
# 17207   29  0.0     21.0                  3                     0.0
# 17208   47  0.0     27.0                  1                     0.0
# 17209   30  1.0     21.0                  8                     0.0
# 17210   59  1.0     21.0                 10                     0.0
# 17211   28  1.0     27.0                  5                     0.0
#
# [17212 rows x 5 columns]

# %% [markdown]
# Model

# %%
from mixed_naive_bayes import MixedNB

#model = GaussianNB()

model = MixedNB(categorical_features=[1,3,4])

# %% [markdown]
# KFold

# %%
k = 5
kf = KFold(n_splits = k, random_state=None)
kf.get_n_splits()

print(kf)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %%
acc_score = []
F1 = []

for train_index, test_index in kf.split(train):
    #print("TRAIN:", train_index)
    #print("TEST:", test_index)

    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    y_train = y_train.values.flatten().astype('int64')

    model.fit(X_train,y_train)

    acc = model.score(X_test , y_test.values.flatten())
    acc_score.append(acc)

    y_preds = model.predict(X_test)
    F1.append(f1_score(y_test, y_preds, average='macro'))


avg_acc_score = sum(acc_score)/k
# Out:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:163: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:350: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:392: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:396: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if y.ndim is not 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:416: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y_classes.size is 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:426: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:163: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:350: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:392: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:396: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if y.ndim is not 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:416: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y_classes.size is 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:426: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:163: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:350: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:392: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:396: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if y.ndim is not 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:416: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y_classes.size is 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:426: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:163: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:350: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:392: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:396: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if y.ndim is not 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:416: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y_classes.size is 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:426: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:163: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.categorical_features is 'all':
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:350: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:392: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if X.ndim is not 2:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:396: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if y.ndim is not 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:416: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if y_classes.size is 1:
# C:\Users\joey-\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:426: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if categorical_features is 'all':
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\CMPT459\data-mining-master\milestone2\code\naive_bayes.ipynb Cell 14' in <module>
#       <a href='vscode-notebook-cell:/c%3A/CMPT459/data-mining-master/milestone2/code/naive_bayes.ipynb#ch0000013?line=8'>9</a> y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#      <a href='vscode-notebook-cell:/c%3A/CMPT459/data-mining-master/milestone2/code/naive_bayes.ipynb#ch0000013?line=10'>11</a> y_train = y_train.values.flatten().astype('int64')
# ---> <a href='vscode-notebook-cell:/c%3A/CMPT459/data-mining-master/milestone2/code/naive_bayes.ipynb#ch0000013?line=12'>13</a> model.fit(X_train,y_train)
#      <a href='vscode-notebook-cell:/c%3A/CMPT459/data-mining-master/milestone2/code/naive_bayes.ipynb#ch0000013?line=14'>15</a> acc = model.score(X_test , y_test.values.flatten())
#      <a href='vscode-notebook-cell:/c%3A/CMPT459/data-mining-master/milestone2/code/naive_bayes.ipynb#ch0000013?line=15'>16</a> acc_score.append(acc)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:133, in MixedNB.fit(self, X, y)
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=130'>131</a> # Validate inputs
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=131'>132</a> self.alpha = _validate_inits(self.alpha)
# --> <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=132'>133</a> X, y = _validate_training_data(
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=133'>134</a>     X, y, self.categorical_features, self.max_categories)
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=135'>136</a> # From https://github.com/scikit-learn/scikit-learn/blob/1495f6924/sklearn/naive_bayes.py#L344
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=136'>137</a> # If the ratio of data variance between dimensions is too small, it
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=137'>138</a> # will cause numerical errors. To address this, we artificially
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=138'>139</a> # boost the variance by epsilon, a small fraction of the standard
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=139'>140</a> # deviation of the largest dimension.
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=140'>141</a> self.epsilon = self.var_smoothing * np.var(X, ddof=1, axis=0).max()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:429, in _validate_training_data(X_raw, y_raw, categorical_features, max_categories)
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=426'>427</a>     categorical_features = np.arange(0, X.shape[1])
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=427'>428</a> for feature_no in categorical_features:
# --> <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=428'>429</a>     if not np.array_equal(X[:, feature_no], X[:, feature_no].astype(int)):
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=429'>430</a>         warnings.warn(f"Feature no. {feature_no} is continuous data. " +
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=430'>431</a>                       "Casting data to integer.")
#     <a href='file:///c%3A/Users/joey-/AppData/Local/Programs/Python/Python39/lib/site-packages/mixed_naive_bayes/mixed_naive_bayes.py?line=431'>432</a>     if max_categories is None:
#
# IndexError: index 5 is out of bounds for axis 1 with size 5

# %% [markdown]
# Repeated Stratified KFold

# %%
# from sklearn.model_selection import RepeatedStratifiedKFold

# rskf = RepeatedStratifiedKFold(n_splits=k, n_repeats=2)

# %%
# acc_score = []
# F1 = []

# for train_index, test_index in rskf.split(X, y):
#     #print("TRAIN:", train_index)
#     #print("TEST:", test_index)

#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     y_train, y_test = y.iloc[train_index], y.iloc[test_index]

#     model.fit(X_train,y_train)

#     acc = model.score(X_test , y_test)
#     acc_score.append(acc)

#     y_preds = model.predict(X_test)
#     F1.append(f1_score(y_test, y_preds, average='macro'))


# avg_acc_score = sum(acc_score)/k

# %%
#print('accuracy of each fold - {}'.format(acc_score))
#print('Avg accuracy : {}'.format(avg_acc_score))
#print('F1 of each fold - {}'.format(F1))
print('Mean F1 : ', np.mean(F1))
# Out:
# Mean F1 :  0.6943270222289798

# %%
test = test.drop(['latitude', 'longitude', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Case_Fatality_Ratio', 'Incident_Rate'], axis=1)

test
# Out:
#       age  sex  province  country  date_confirmation  chronic_disease_binary
# 0      59  0.0      50.0     27.0                  1                       0
# 1      79  1.0      65.0     21.0                  8                       0
# 2      44  0.0      65.0     21.0                  6                       0
# 3      36  1.0      65.0     21.0                  3                       0
# 4      52  1.0       7.0     21.0                  2                       0
# ...   ...  ...       ...      ...                ...                     ...
# 4299   66  1.0      36.0     21.0                  1                       0
# 4300   66  1.0      50.0     27.0                  1                       0
# 4301   53  0.0      65.0     21.0                  5                       0
# 4302   25  1.0      65.0     21.0                  8                       0
# 4303   34  1.0      36.0     21.0                  8                       0
#
# [4304 rows x 6 columns]

# %% [markdown]
# Generating Result

# %%
y_preds = model.predict(test)

y_preds

def create_submission_file(y_preds, file_name):
    with open(file_name, 'w') as csvfile:
        wr = csv.writer(csvfile, quoting=csv.QUOTE_ALL)
        wr.writerow(["Id", "Prediction"])
        for i, pred in enumerate(y_preds):
            wr.writerow([str(i), str(int(pred))])

        
create_submission_file(y_preds, 'submission_[naive_bayes].csv')
